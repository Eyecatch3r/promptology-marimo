# %%
import pandas as pd
from zipfile import ZipFile

# %%
df = pd.read_csv(ZipFile('corpus.csv.zip').open('corpus.csv'))

# %%
df
# Out:
#          gender    age residence      civil_status            denomination  \
# 0      Männlich  18-34     Stadt  In Partnerschaft  Evangelisch-reformiert
# 1      Männlich  18-34     Stadt  In Partnerschaft  Evangelisch-reformiert
# 2      Männlich  18-34     Stadt  In Partnerschaft  Evangelisch-reformiert
# 3      Männlich  18-34     Stadt  In Partnerschaft  Evangelisch-reformiert
# 4      Männlich  18-34     Stadt  In Partnerschaft  Evangelisch-reformiert
# ...         ...    ...       ...               ...                     ...
# 12753  Männlich  50-64      Land       Verheiratet      Römisch-katholisch
# 12754  Männlich  35-49      Land             Ledig  Evangelisch-reformiert
# 12755  Männlich  35-49      Land             Ledig  Evangelisch-reformiert
# 12756  Männlich  35-49      Land             Ledig  Evangelisch-reformiert
# 12757  Männlich  35-49      Land             Ledig  Evangelisch-reformiert
#
#          education     political_spectrum  argument_id  \
# ...
