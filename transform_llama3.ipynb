# %%
import pandas as pd

# %%
df = pd.read_json("output/llama3.1-8B-instruct_de.jsonl", lines=True)
df.shape
# Out:
# (45822, 4)

# %%
df.head()
# Out:
#      id               timestamp                         model  \
# 0  de_0 2025-09-03 20:01:15.564  llama3.1-8b-instruct_de.json
# 1  de_1 2025-09-03 20:01:15.564  llama3.1-8b-instruct_de.json
# 2  de_2 2025-09-03 20:01:15.564  llama3.1-8b-instruct_de.json
# 3  de_3 2025-09-03 20:01:15.564  llama3.1-8b-instruct_de.json
# 4  de_4 2025-09-03 20:01:15.564  llama3.1-8b-instruct_de.json
#
#                                             response
# 0  Ich bin für die Abschaffung der Plafonierung, ...
# 1  Die Plafonierung der Renten bei Ehepaaren ist ...
# 2  Ich bin für die Abschaffung der Plafonierung. ...
# 3  Ich bin dafür, dass die Renteplafonierung abge...
# 4  Die Plafonierung der Rente ist eine Regel, die...

# %%
df.to_csv("output/llama3.1-8B-instruct_de.csv", index=False)
