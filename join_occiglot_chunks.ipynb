# %%
import pandas as pd

# %%
df1 = pd.read_json("output/occiglot-7b-eu5-instruct_de_chunk1.jsonl", lines=True)
df2 = pd.read_json("output/occiglot-7b-eu5-instruct_de_chunk2.jsonl", lines=True)

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#      id               timestamp                     model  \
# 0  de_0 2025-09-14 15:35:40.667  occiglot-7b-eu5-instruct
# 1  de_1 2025-09-14 15:35:40.667  occiglot-7b-eu5-instruct
# 2  de_2 2025-09-14 15:35:40.667  occiglot-7b-eu5-instruct
# 3  de_3 2025-09-14 15:35:40.667  occiglot-7b-eu5-instruct
# 4  de_4 2025-09-14 15:35:40.667  occiglot-7b-eu5-instruct
#
#                                             response
# 0  </s></s></s></s><s><|im_start|> system\nYou ar...
# 1  <s><|im_start|> system\nYou are a helpful assi...
# 2  </s></s></s></s></s></s></s><s><|im_start|> sy...
# 3  </s></s></s></s></s><s><|im_start|> system\nYo...
# 4  </s><s><|im_start|> system\nYou are a helpful ...

# %%
df.to_json("output/occiglot-7b-eu5-instruct_de.jsonl", lines=True, orient="records")

# %%
df1 = pd.read_json("output/occiglot-7b-eu5-instruct_fr_chunk1.jsonl", lines=True)
df2 = pd.read_json("output/occiglot-7b-eu5-instruct_fr_chunk2.jsonl", lines=True)
df = pd.concat([df1, df2])
df.to_json("output/occiglot-7b-eu5-instruct_fr.jsonl", lines=True, orient="records")
