# %%
import pandas as pd

# %%
df = pd.read_json("output/occiglot-7b-eu5-instruct_de.jsonl", lines=True)

# %%
df[:int((len(df)/2))].shape
# Out:
# (22911, 4)

# %%
df[:int((len(df)/2))].to_json("output/occiglot-7b-eu5-instruct_de_chunk1.jsonl", orient="records", lines=True)

# %%
df[int((len(df)/2)):].to_json("output/occiglot-7b-eu5-instruct_de_chunk2.jsonl", orient="records", lines=True)
